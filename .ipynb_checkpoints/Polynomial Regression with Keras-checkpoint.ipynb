# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.
# c:\users\aditya\miniconda3\envs\py36\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
np.random.seed(42)
points = 1000
X = np.linspace(-3, 3, points)
# The sin fucntions got nice result generating 500 points
# but sin*cos was good only with 1000 points(more complex more poitns nedded)
#y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)
y = np.sin(X)*np.cos(X)  + np.random.uniform(-0.5, 0.5, points)

# %%
plt.scatter(X, y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
# model.add(Dropout(0.5))
# model.add(Dense(30, activation='sigmoid'))
# model.add(Dropout(0.5))
# model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
history = model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 209us/step - loss: 0.2290
# Epoch 2/50
# 1000/1000 [==============================] - 0s 44us/step - loss: 0.1979
# Epoch 3/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1940
# Epoch 4/50
# 1000/1000 [==============================] - 0s 41us/step - loss: 0.1942
# Epoch 5/50
# 1000/1000 [==============================] - 0s 41us/step - loss: 0.1950
# Epoch 6/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.2104
# Epoch 7/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.2041
# Epoch 8/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.1993
# Epoch 9/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.1987
# Epoch 10/50
# 1000/1000 [==============================] - 0s 44us/step - loss: 0.1996
# Epoch 11/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.2000
# Epoch 12/50
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.1985
# Epoch 13/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1928
# Epoch 14/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1955
# Epoch 15/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1955
# Epoch 16/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1980
# Epoch 17/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.2095
# Epoch 18/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1968
# Epoch 19/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.2097
# Epoch 20/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1965
# Epoch 21/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.2005
# Epoch 22/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1953
# Epoch 23/50
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.1919
# Epoch 24/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.1966
# Epoch 25/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1940
# Epoch 26/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1968
# Epoch 27/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1891
# Epoch 28/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.1880
# Epoch 29/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.1907
# Epoch 30/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.1896
# Epoch 31/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1894
# Epoch 32/50
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.1878
# Epoch 33/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1867
# Epoch 34/50
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.1867
# Epoch 35/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.1848
# Epoch 36/50
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.1821
# Epoch 37/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.1817
# Epoch 38/50
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.1805
# Epoch 39/50
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.1807
# Epoch 40/50
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.1784
# Epoch 41/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.1761
# Epoch 42/50
# 1000/1000 [==============================] - 0s 54us/step - loss: 0.1751
# Epoch 43/50
# 1000/1000 [==============================] - 0s 47us/step - loss: 0.1672
# Epoch 44/50
# 1000/1000 [==============================] - 0s 61us/step - loss: 0.1583
# Epoch 45/50
# 1000/1000 [==============================] - 0s 45us/step - loss: 0.1311
# Epoch 46/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.1100
# Epoch 47/50
# 1000/1000 [==============================] - 0s 44us/step - loss: 0.1090
# Epoch 48/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.1028
# Epoch 49/50
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.1088
# Epoch 50/50
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.1076

# %%
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.legend(['training'])
plt.title('Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5,0,'epoch')

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
